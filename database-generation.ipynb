# %%
import pandas as pd
import sqlite3

# Load CSV into a DataFrame
df = pd.read_csv("/kaggle/input/new-da/processed_dataset1.csv")

# Create SQLite Database
conn = sqlite3.connect("dataset_new.db")
df.to_sql("anomaly_data", conn, if_exists="replace", index=False)

# Function to update counts dynamically (increment or decrement)
def update_count(image_name, column_name, change_by=1):
    """
    Update the counter for a specific image and column in the database (increment or decrement).

    Args:
        image_name (str): The name of the image whose count needs updating.
        column_name (str): The column to update (e.g., 'Fight_Count').
        change_by (int): The value to change the count by (positive to increment, negative to decrement).
    """
    try:
        # Check if the column exists
        cursor = conn.execute(f"PRAGMA table_info(anomaly_data)")
        columns = [info[1] for info in cursor.fetchall()]
        if column_name not in columns:
            print(f"Column '{column_name}' does not exist in the database.")
            return
        
        # Update the count
        conn.execute(f"""
            UPDATE anomaly_data
            SET {column_name} = {column_name} + ?
            WHERE Image = ?
        """, (change_by, image_name))
        
        conn.commit()
        print(f"Updated {column_name} for {image_name} by {change_by}.")
    except Exception as e:
        print(f"Error: {e}")

# Example Usage
update_count("qr261_jpg.rf.b28d97a7151ce82f83a9d6e9e6b28293.jpg", "ItemFall_Count", -1)  # Decrement ItemFall_Count by 1
update_count("101_png.rf.025d2c1f958a97f58d5ca6072cf49b03.jpg", "Fight_Count", 3)       # Increment Fight_Count by 3
update_count("102_png.rf.c5baf2bbfd6dbbd211db7a084ba69e7b.jpg", "Total_Objects", -5)   # Decrement Total_Objects by 5

# Verify Updates
updated_df = pd.read_sql_query("SELECT * FROM anomaly_data", conn)
print(updated_df)

# Close the connection
conn.close()
# Out:
# Column 'ItemFall_Count' does not exist in the database.
# Column 'Fight_Count' does not exist in the database.
# Updated Total_Objects for 102_png.rf.c5baf2bbfd6dbbd211db7a084ba69e7b.jpg by -5.
#             Dataset                                              Image  Fight  \
# 0            Normal      0_png.rf.7c2d6fe95618f92a58fbfd7d10936b9b.jpg    0.0
# 1            Normal      0_png.rf.96d0b96c50993c8fa8472c7b8fd4d523.jpg    0.0
# 2            Normal      0_png.rf.d227cd7e0b1c0727a9d9ffd3ed1636ab.jpg    0.0
# 3            Normal    101_png.rf.025d2c1f958a97f58d5ca6072cf49b03.jpg    0.0
# 4            Normal    101_png.rf.8bc57bd69f1c26c4895101b0af578298.jpg    0.0
# 5            Normal    101_png.rf.9771cfe4a3c9303d69a9468cd5f7043c.jpg    0.0
# 6            Normal    102_png.rf.912bd2894a311aeb3b6dc59e93620fc4.jpg    0.0
# 7            Normal    102_png.rf.c5baf2bbfd6dbbd211db7a084ba69e7b.jpg    0.0
# 8            Normal    102_png.rf.e97d0012ded6c8489237be52303cee4b.jpg    0.0
# 9            Normal    103_png.rf.02bc1df7fb48d3b9972c1b57a78716fd.jpg    0.0
# 10        Anomalies  qr260_jpg.rf.82ea9b3ab5cee378e1527ad7b6e68b2d.jpg    0.0
# 11        Anomalies  qr261_jpg.rf.b28d97a7151ce82f38a9d6e9e62b2893.jpg    0.0
# 12        Anomalies  qr262_jpg.rf.ab1841bef1f998fb2a3f0112817fc86f.jpg    0.0
# 13        Anomalies  qr263_jpg.rf.74466216483c0b027cc0b549d9605b02.jpg    0.0
# 14        Anomalies  qr265_jpg.rf.ce9aed1338f7ddc1c0f047824964540b.jpg    0.0
# 15        Anomalies  qr267_jpg.rf.b66e3bce3c4d8c3d0eadd2e3455fa0df.jpg    0.0
# 16        Anomalies  qr268_jpg.rf.1e7936db0c654e3bcb4d096d38694bc4.jpg    0.0
# 17        Anomalies  qr269_jpg.rf.47315d159338ad97cfe54ab4addad2ec.jpg    0.0
# 18        Anomalies   qr26_jpg.rf.ff8fe3e5c46f7e08fbe8637fcbbec69f.jpg    0.0
# 19        Anomalies  qr271_jpg.rf.387a3aa2e3068ef5163f3df83261c0ad.jpg    0.0
# 20        Rack Fall  7bb31597-81e7-4c8d-b796-29fbb998a5a2_jpeg.rf.e...    0.0
# 21        Rack Fall  WhatsApp-Image-2024-11-16-at-1-01-29-AM_jpeg.r...    0.0
# 22        Rack Fall  WhatsApp-Image-2024-11-16-at-1-03-56-AM_jpeg.r...    0.0
# 23        Rack Fall  WhatsApp-Image-2024-11-16-at-1-42-18-AM_jpeg.r...    0.0
# 24        Rack Fall  f9fc99b2-3704-430d-a852-6cecc94a55c9_jpeg.rf.c...    0.0
# 25  Fight Detection  WhatsApp-Image-2024-11-16-at-2-03-32-AM_jpeg.r...    1.0
# 26  Fight Detection  WhatsApp-Image-2024-11-16-at-2-04-13-AM_jpeg.r...    1.0
# 27  Fight Detection  WhatsApp-Image-2024-11-16-at-2-17-46-AM_jpeg.r...    1.0
# 28  Fight Detection  WhatsApp-Image-2024-11-16-at-2-19-54-AM_jpeg.r...    1.0
# 29  Fight Detection  WhatsApp-Image-2024-11-16-at-2-21-26-AM_jpeg.r...    1.0
#
#     ItemFall  RackFall  Total_Objects  Rack_Number
# 0        0.0       0.0             30            1
# 1        0.0       0.0             30            2
# 2        0.0       0.0             30            3
# 3        0.0       0.0              6            4
# 4        0.0       0.0              6            5
# 5        0.0       0.0              6            6
# 6        0.0       0.0              2            7
# 7        0.0       0.0             -3            8
# 8        0.0       0.0              2            9
# 9        0.0       0.0              2           10
# 10       1.0       0.0              1           21
# 11       1.0       0.0              3           22
# 12       1.0       0.0              2           23
# 13       1.0       0.0              1           24
# 14       1.0       0.0              1           25
# 15       1.0       0.0              1           26
# 16       1.0       0.0              1           27
# 17       1.0       0.0              1           28
# 18       1.0       0.0              2           29
# 19       1.0       0.0              1           30
# 20       0.0       1.0              1           11
# 21       0.0       1.0              2           12
# 22       0.0       1.0              4           13
# 23       0.0       1.0              1           14
# 24       0.0       1.0              1           20
# 25       0.0       0.0              2           15
# 26       0.0       0.0              1           16
# 27       0.0       0.0              1           17
# 28       0.0       0.0              1           18
# 29       0.0       0.0              1           19

# %%
import sqlite3

# Connect to the database
connection = sqlite3.connect("/kaggle/working/dataset.db")
cursor = connection.cursor()

# Query the `anomaly_data` table
cursor.execute("SELECT * FROM anomaly_data")
rows = cursor.fetchall()

# Print the results
print("Data in the 'anomaly_data' table:")
for row in rows:
    print(row)

# Close the connection
connection.close()
# Out:
# Data in the 'anomaly_data' table:
# ('Normal', '0_png.rf.7c2d6fe95618f92a58fbfd7d10936b9b.jpg', 0, 0, 0, 30)
# ('Normal', '0_png.rf.96d0b96c50993c8fa8472c7b8fd4d523.jpg', 0, 0, 0, 30)
# ('Normal', '0_png.rf.d227cd7e0b1c0727a9d9ffd3ed1636ab.jpg', 0, 0, 0, 30)
# ('Normal', '101_png.rf.025d2c1f958a97f58d5ca6072cf49b03.jpg', 3, 0, 0, 6)
# ('Normal', '101_png.rf.8bc57bd69f1c26c4895101b0af578298.jpg', 0, 0, 0, 6)
# ('Normal', '101_png.rf.9771cfe4a3c9303d69a9468cd5f7043c.jpg', 0, 0, 0, 6)
# ('Normal', '102_png.rf.912bd2894a311aeb3b6dc59e93620fc4.jpg', 0, 0, 0, 2)
# ('Normal', '102_png.rf.c5baf2bbfd6dbbd211db7a084ba69e7b.jpg', 0, 0, 0, -3)
# ('Normal', '102_png.rf.e97d0012ded6c8489237be52303cee4b.jpg', 0, 0, 0, 2)
# ('Normal', '103_png.rf.02bc1df7fb48d3b9972c1b57a78716fd.jpg', 0, 0, 0, 2)
# ('Anomalies', 'qr260_jpg.rf.82ea9b3ab5cee378e1527ad7b6e68b2d.jpg', 0, 0, 0, 1)
# ('Anomalies', 'qr261_jpg.rf.b28d97a7151ce82f38a9d6e9e62b2893.jpg', 0, 0, 0, 3)
# ('Anomalies', 'qr262_jpg.rf.ab1841bef1f998fb2a3f0112817fc86f.jpg', 0, 0, 0, 2)
# ('Anomalies', 'qr263_jpg.rf.74466216483c0b027cc0b549d9605b02.jpg', 0, 0, 0, 1)
# ('Anomalies', 'qr265_jpg.rf.ce9aed1338f7ddc1c0f047824964540b.jpg', 0, 0, 0, 1)
# ('Anomalies', 'qr267_jpg.rf.b66e3bce3c4d8c3d0eadd2e3455fa0df.jpg', 0, 0, 0, 1)
# ('Anomalies', 'qr268_jpg.rf.1e7936db0c654e3bcb4d096d38694bc4.jpg', 0, 0, 0, 1)
# ('Anomalies', 'qr269_jpg.rf.47315d159338ad97cfe54ab4addad2ec.jpg', 0, 0, 0, 1)
# ('Anomalies', 'qr26_jpg.rf.ff8fe3e5c46f7e08fbe8637fcbbec69f.jpg', 0, 0, 0, 2)
# ('Anomalies', 'qr271_jpg.rf.387a3aa2e3068ef5163f3df83261c0ad.jpg', 0, 0, 0, 1)
# ('Rack Fall', '7bb31597-81e7-4c8d-b796-29fbb998a5a2_jpeg.rf.e95d8e2a37425411a6d4459b87dc878f.jpg', 0, 0, 0, 1)
# ('Rack Fall', 'WhatsApp-Image-2024-11-16-at-1-01-29-AM_jpeg.rf.f1e7a33603a00695948556004cba2c5a.jpg', 0, 0, 0, 2)
# ('Rack Fall', 'WhatsApp-Image-2024-11-16-at-1-03-56-AM_jpeg.rf.0b85ba161e11f5d5ffbf493522ad8cca.jpg', 0, 0, 0, 4)
# ('Rack Fall', 'WhatsApp-Image-2024-11-16-at-1-42-18-AM_jpeg.rf.17edd80e8dd96119ee451cb67c28c559.jpg', 0, 0, 0, 1)
# ('Rack Fall', 'f9fc99b2-3704-430d-a852-6cecc94a55c9_jpeg.rf.c656025ed16d7d33f043ed2ea3649a35.jpg', 0, 0, 0, 1)
# ('Fight Detection', 'WhatsApp-Image-2024-11-16-at-2-03-32-AM_jpeg.rf.5ce5821f237ee9a69eb018301d684dba.jpg', 0, 0, 0, 2)
# ('Fight Detection', 'WhatsApp-Image-2024-11-16-at-2-04-13-AM_jpeg.rf.4a5ad0319ca05a4651ab532f204b99cd.jpg', 0, 0, 0, 1)
# ('Fight Detection', 'WhatsApp-Image-2024-11-16-at-2-17-46-AM_jpeg.rf.ed6867ddb4236d7ac9c53b9e7efe687a.jpg', 0, 0, 0, 1)
# ('Fight Detection', 'WhatsApp-Image-2024-11-16-at-2-19-54-AM_jpeg.rf.c9bf12c73bbee949230a40c9dc745319.jpg', 0, 0, 0, 1)
# ('Fight Detection', 'WhatsApp-Image-2024-11-16-at-2-21-26-AM_jpeg.rf.b01fa53b31a375c54d5efb6229afb9bc.jpg', 0, 0, 0, 1)
